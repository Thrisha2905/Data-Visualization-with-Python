# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
X=pd.read_csv('canadian_immegration_data.csv')
X
# Out:
#             Country Continent              Region             DevName  1980  \
# 0       Afghanistan      Asia       Southern Asia  Developing regions    16
# 1           Albania    Europe     Southern Europe   Developed regions     1
# 2           Algeria    Africa     Northern Africa  Developing regions    80
# 3    American Samoa   Oceania           Polynesia  Developing regions     0
# 4           Andorra    Europe     Southern Europe   Developed regions     0
# ..              ...       ...                 ...                 ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  Developing regions  1191
# 191  Western Sahara    Africa     Northern Africa  Developing regions     0
# 192           Yemen      Asia        Western Asia  Developing regions     1
# 193          Zambia    Africa      Eastern Africa  Developing regions    11
# 194        Zimbabwe    Africa      Eastern Africa  Developing regions    72
#
# ...

# %%
X.sort_values(['Total'], ascending = False, axis = 0, inplace = True)
X
# Out:
#                                                Country Continent  \
# 79                                               India      Asia
# 36                                               China      Asia
# 183  United Kingdom of Great Britain and Northern I...    Europe
# 136                                        Philippines      Asia
# 130                                           Pakistan      Asia
# ..                                                 ...       ...
# 149                                         San Marino    Europe
# 123                                      New Caledonia   Oceania
# 109                                   Marshall Islands   Oceania
# 191                                     Western Sahara    Africa
# 131                                              Palau   Oceania
#
#                  Region             DevName   1980   1981   1982   1983  \
# 79        Southern Asia  Developing regions   8880   8670   8147   7338
# ...

# %%
#generating area plots
years = list(map(str, range(1980, 2014)))
X_top5 = X.head()
X_top5 = X_top5[years].transpose()
Y=X_top5.head(40)
Y
# Out:
#         79     36     183    136    130
# 1980   8880   5123  22045   6051    978
# 1981   8670   6682  24796   5921    972
# 1982   8147   3308  20620   5249   1201
# 1983   7338   1863  10015   4562    900
# 1984   5704   1527  10170   3801    668
# 1985   4211   1816   9564   3150    514
# 1986   7150   1960   9470   4166    691
# 1987  10189   2643  21337   7360   1072
# 1988  11522   2758  27359   8639   1334
# 1989  10343   4323  23795  11865   2261
# 1990  12041   8076  31668  12509   2470
# 1991  13734  14255  23380  12718   3079
# 1992  13673  10846  34123  13670   4071
# 1993  21496   9817  33720  20479   4777
# 1994  18620  13128  39231  19532   4666
# 1995  18489  14398  30145  15864   4994
# 1996  23859  19415  29322  13692   9125
# 1997  22268  20475  22965  11549  13073
# 1998  17241  21049  10367   8735   9068
# 1999  18974  30069   7045   9734   9979
# 2000  28572  35529   8840  10763  15400
# 2001  31223  36434  11728  13836  16708
# ...

# %%
Y.plot(kind='area')
plt.title('Imigration trend of top 5 countries')
plt.ylabel('number of imigration')
plt.xlabel('years')
plt.show()

# %%
#generating histogram
count, bin_edges = np.histogram(X['2013'])
X['2013'].plot(kind='hist',xticks = bin_edges)
plt.title('Histogram of Imigration from 195 countries in 2013')
plt.ylabel('Number of countries')
plt.xlabel('Number of Imigrants')
plt.show()

# %%
#generating pie chart
X_continents = X.groupby('Continent', axis = 0).sum()
X_continents
# Out:
# C:\Users\Thrisha Reddy\AppData\Local\Temp\ipykernel_18540\2143421820.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   X_continents = X.groupby('Continent', axis = 0).sum()
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
# Oceania                           1942   1839   1675   1018    878    920
#
#                                   1986   1987   1988   1989  ...    2005  \
# ...

# %%
X_continents['Total'].plot(kind='pie')
plt.title('Immigrations to canada by continent [1980-2013]')
plt.show()

# %%
X.max()
# Out:
# Country                Zimbabwe
# Continent               Oceania
# Region           Western Europe
# DevName      Developing regions
# 1980                      22045
# 1981                      24796
# 1982                      20620
# 1983                      10015
# 1984                      10170
# 1985                       9564
# 1986                       9470
# 1987                      21337
# 1988                      27359
# 1989                      23795
# 1990                      31668
# 1991                      23380
# 1992                      34123
# 1993                      33720
# 1994                      39231
# 1995                      30145
# 1996                      29322
# 1997                      22965
# 1998                      21049
# 1999                      30069
# 2000                      35529
# 2001                      36434
# 2002                      31961
# 2003                      36439
# 2004                      36619
# ...

# %%
#generating scatter plot
X.plot(kind='scatter',x='Country',y='Total')
plt.show()

# %%
#seaborn usage-regression plots
#take new dataset
df=pd.read_csv('Newdataset.csv')
df
# Out:
#     years  Total
# 0    1980  58639
# 1    1981  15699
# 2    1982  69439
# 3    1983      6
# 4    1984     15
# 5    1985   2113
# 6    1986    981
# 7    1987  19596
# 8    1988   3310
# 9    1989  23829
# 10   1990   4985
# 11   1991   2649
# 12   1992    808
# 13   1993    475
# 14   1994  65568
# 15   1995   6923
# 16   1996   7975
# 17   1997  10762
# 18   1998   1083
# 19   1999   2852
# 20   2000   5876
# 21   2001   3205
# 22   2002  21855
# 23   2003    396
# 24   2004  29659
# 25   2005    600
# 26   2006  23310
# 27   2007   2043
# 28   2008   8110
# 29   2009    201
# 30   2010   6538
# 31   2011  16021
# 32   2012     20
# 33   2013    550

# %%
#use seaborn function to plot
ax = sns.regplot(x='years',y='Total',data=df)

# %%
#generating scatter plot for this dataset
df.plot(kind='scatter',x='years',y='Total')
plt.show()

# %%
ax=sns.regplot(x='years',y='Total',data=df,color='red',marker='*')

# %%
df.plot(kind='scatter',x='years',y='Total',color='red',marker='*')
plt.show()

# %%
import folium
#folium usage
#define the world map centered around canada with a low zoom level
world_map=folium.Map(location=[56.130,-106.35],zoom_start=4)
#display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#marking on map
#generating map of canada
canada_map=folium.Map(location=[56.130,-106.35],zoom_start=4)
#add a red marker to Ontorio
#create a feature group
ontario=folium.map.FeatureGroup()
#style the feature group
ontario.add_child(
    folium.features.CircleMarker(
        [51.25,-85.32],radius = 5,color='red',fill_color='Red'
        )
    )
#add the feature group to the map
canada_map.add_child(ontario)
#label the marker
folium.Marker([51.25,-85.32],popup='Ontario').add_to(canada_map)
#display map
canada_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#generating choropleth maps
#create a plain world map
world_map=folium.Map(zoom_start=2,tiles='Mapbox Bright')
##geojaon file
world_geo=r'world_countries.jaon'
#generate choropleth map using the total
#population of each country to canada from 1980 to 2013
world_map.choropleth(
    geo_path=world_geo,
    data=X,
    columns=['Country','Total'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    legend_name='immigration to canada'
)
#display map
world_map
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 #generating choropleth maps
#       2 #create a plain world map
# ----> 3 world_map=folium.Map(zoom_start=2,tiles='Mapbox Bright')
#       4 ##geojaon file
#       5 world_geo=r'world_countries.jaon'
#
# File ~\anaconda3\lib\site-packages\folium\folium.py:307, in Map.__init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, **kwargs)
#     305     self.add_child(tiles)
#     306 elif tiles:
# --> 307     tile_layer = TileLayer(
#     308         tiles=tiles, attr=attr, min_zoom=min_zoom, max_zoom=max_zoom
#     309     )
#     310     self.add_child(tile_layer, name=tile_layer.tile_name)
#
# ...
