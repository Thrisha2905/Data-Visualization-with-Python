# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.plot(5, 5, 'o')
plt.show()

# %%
#we use notebook for labeling x and y values after plotting the graph
# %matplotlib notebook

# %%
plt.plot(5, 5, '*')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Plotting sample')
# Out:
# Text(0.5, 1.0, 'Plotting sample')

# %%
#we can also use the pandas function for plotting for the whole data set using the function kind=line
#lets take a sample dataset
data=pd.DataFrame({"Shoes":[75,60,85],"Price":[82,65,90]})
data
# Out:
#    Shoes  Price
# 0     75     82
# 1     60     65
# 2     85     90

# %%
data.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
plt.xlabel='X'
plt.ylabel='Y'
plt.title('Shoes prices')
# Out:
# Text(0.5, 1.0, 'Shoes prices')

# %%
data.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.scatter(x='Shoes',y='Price')
# Out:
# <AxesSubplot:xlabel='Shoes', ylabel='Price'>

# %%
Shoes=list(map(str,range(60,85)))
data.loc['Price','Shoes'].plot(kind='line')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 Shoes=list(map(str,range(60,85)))
# ----> 2 data.loc['Price','Shoes'].plot(kind='line')
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
# ...
